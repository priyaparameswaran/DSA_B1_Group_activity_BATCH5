# %% [markdown]
# # Competition Group 5

# %% [markdown]
# ## Dataset on Transportation

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0bf125a7-a0eb-4efd-8da5-a85064ff4396" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0bf125a7-a0eb-4efd-8da5-a85064ff4396">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cardekho_updated.csv to cardekho_updated.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data_set1=pd.read_csv('cardekho_updated.csv')
data_set1
# Out:
#                                             full_name  ...   seats
# 0                                     Maruti Alto Std  ...  Seats5
# 1                              Hyundai Grand i10 Asta  ...  Seats5
# 2                                    Hyundai i20 Asta  ...  Seats5
# 3                       Maruti Alto K10 2010-2014 VXI  ...  Seats5
# 4      Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV  ...  Seats5
# ...                                               ...  ...     ...
# 19969                   Toyota Platinum Etios 1.4 GXD  ...  Seats5
# 19970                          Maruti Ertiga BSIV VXI  ...  Seats7
# 19971                    Skoda Rapid 1.5 TDI Elegance  ...  Seats5
# 19972                          Mahindra XUV500 W6 2WD  ...  Seats7
# 19973                        Honda City i-VTEC CVT VX  ...  Seats5
#
# [19974 rows x 13 columns]

# %%
data_set1.shape
# Out:
# (19974, 13)

# %%
data_set1.info
# Out:
# <bound method DataFrame.info of                                             full_name  ...   seats
# 0                                     Maruti Alto Std  ...  Seats5
# 1                              Hyundai Grand i10 Asta  ...  Seats5
# 2                                    Hyundai i20 Asta  ...  Seats5
# 3                       Maruti Alto K10 2010-2014 VXI  ...  Seats5
# 4      Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV  ...  Seats5
# ...                                               ...  ...     ...
# 19969                   Toyota Platinum Etios 1.4 GXD  ...  Seats5
# 19970                          Maruti Ertiga BSIV VXI  ...  Seats7
# 19971                    Skoda Rapid 1.5 TDI Elegance  ...  Seats5
# 19972                          Mahindra XUV500 W6 2WD  ...  Seats7
# 19973                        Honda City i-VTEC CVT VX  ...  Seats5
#
# [19974 rows x 13 columns]>

# %%
data_set1.describe()
# Out:
#                year
# count  19974.000000
# mean    2014.526134
# std        3.248791
# min     1991.000000
# 25%     2013.000000
# 50%     2015.000000
# 75%     2017.000000
# max     2021.000000

# %%
data_set1.isna().sum()
# Out:
# full_name                0
# selling_price            0
# new_price            10410
# year                     0
# seller_type              0
# km_driven                0
# owner_type               0
# fuel_type                0
# transmission_type        0
# mileage                160
# engine                 110
# max_power              337
# seats                   87
# dtype: int64

# %%
data_set1.dtypes
# Out:
# full_name            object
# selling_price        object
# new_price            object
# year                  int64
# seller_type          object
# km_driven            object
# owner_type           object
# fuel_type            object
# transmission_type    object
# mileage              object
# engine               object
# max_power            object
# seats                object
# dtype: object

# %% [markdown]
# ### Cleaning the data

# %%
#data_set1['selling_price']= data_set1['selling_price'].astype(float, errors = 'raise')
#data_set1['selling_price'] = pd.to_numeric(data_set1['selling_price'],downcast = 'float')

##data_set1["selling_price"] = pd.to_numeric(data_set1["selling_price"], downcast="float")

# %%
data_set1.dtypes
# Out:
# full_name            object
# selling_price        object
# new_price            object
# year                  int64
# seller_type          object
# km_driven            object
# owner_type           object
# fuel_type            object
# transmission_type    object
# mileage              object
# engine               object
# max_power            object
# seats                object
# dtype: object

# %%
for i in range(data_set1.shape[0]):
    try:
        price = float(data_set1['selling_price'][i].split(' ')[0])
        digit = data_set1['selling_price'][i].split(' ')[1]
        #price = float(data_set1['selling_price'][i])
        #digit = data_set1['selling_price'][i]
        if digit == 'Lakh*':
            price = price * 100000
            data_set1['selling_price'][i] = price
        elif digit == 'Cr*':
            price = price * 10000000
            data_set1['selling_price'][i] = price
    except:
        price = data_set1['selling_price'][i][:-1]
        price = price.replace(',', '')
        data_set1['selling_price'][i] = float(price)
data_set1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
#                                             full_name  ...   seats
# 0                                     Maruti Alto Std  ...  Seats5
# 1                              Hyundai Grand i10 Asta  ...  Seats5
# 2                                    Hyundai i20 Asta  ...  Seats5
# 3                       Maruti Alto K10 2010-2014 VXI  ...  Seats5
# 4      Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV  ...  Seats5
# ...                                               ...  ...     ...
# 19969                   Toyota Platinum Etios 1.4 GXD  ...  Seats5
# 19970                          Maruti Ertiga BSIV VXI  ...  Seats7
# 19971                    Skoda Rapid 1.5 TDI Elegance  ...  Seats5
# 19972                          Mahindra XUV500 W6 2WD  ...  Seats7
# 19973                        Honda City i-VTEC CVT VX  ...  Seats5
#
# [19974 rows x 13 columns]

# %%
data_set1['selling_price']= data_set1['selling_price'].astype(float, errors = 'raise')
data_set1.dtypes
# Out:
# full_name             object
# selling_price        float64
# new_price             object
# year                   int64
# seller_type           object
# km_driven             object
# owner_type            object
# fuel_type             object
# transmission_type     object
# mileage               object
# engine                object
# max_power             object
# seats                 object
# dtype: object

# %%
data_set1['km_driven'] = data_set1['km_driven'].str.split(' ', n=1, expand=True)[0]
data_set1['km_driven'] = data_set1['km_driven'].str.replace(',','')
# Mileage
data_set1['mileage'] = data_set1['mileage'].str.split(' ', expand=True)[0].str.split('e', expand=True)[2]
# Engine
data_set1['engine'] = data_set1['engine'].str.split(' ', expand=True)[0].str.split('e',expand=True)[1]
# Max Power
data_set1['max_power'] = data_set1['max_power'].str.split(' ', expand=True)[1].str.split('r',expand=True)[1]
# Seats 
data_set1['seats'] = data_set1['seats'].str.split('s', expand=True)[1]

# %%
data_set1['km_driven']= data_set1['km_driven'].astype(float, errors = 'raise')
data_set1['mileage']= data_set1['mileage'].astype(float, errors = 'raise')
data_set1['engine']= data_set1['engine'].astype(float, errors = 'raise')
data_set1['max_power']= data_set1['max_power'].astype(float, errors = 'raise')
data_set1['seats']= data_set1['seats'].astype(float, errors = 'raise')

# %%
data_set1.dtypes
# Out:
# full_name             object
# selling_price        float64
# new_price             object
# year                   int64
# seller_type           object
# km_driven            float64
# owner_type            object
# fuel_type             object
# transmission_type     object
# mileage              float64
# engine               float64
# max_power            float64
# seats                float64
# dtype: object

# %% [markdown]
# ### Filling Missing values

# %%
data_set1.isna().sum()
# Out:
# full_name                0
# selling_price            0
# new_price            10410
# year                     0
# seller_type              0
# km_driven                0
# owner_type               0
# fuel_type                0
# transmission_type        0
# mileage                160
# engine                 110
# max_power              337
# seats                   87
# dtype: int64

# %%
obj_cols = list(data_set1.select_dtypes('object').columns)
for o in obj_cols:
  data_set1[o].fillna('NULL',inplace = True)

# %%
obj_cols = list(data_set1.select_dtypes('float').columns)
for o in obj_cols:
  data_set1[o].fillna('NULL',inplace = True)

# %%
data_set1.isna().sum()
# Out:
# full_name            0
# selling_price        0
# new_price            0
# year                 0
# seller_type          0
# km_driven            0
# owner_type           0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# dtype: int64

# %% [markdown]
# ### Handling outliers

# %%
sns.boxplot(data= data_set1)
plt.show()

# %%
plt.boxplot(data_set1['year'])
plt.title('Box plot of year')
# Out:
# Text(0.5, 1.0, 'Box plot of year')

# %%
Q1=np.percentile(data_set1['year'],25,interpolation='midpoint')
Q2=np.percentile(data_set1['year'],50,interpolation='midpoint')
Q3=np.percentile(data_set1['year'],75,interpolation='midpoint')
print('Q1 = ',Q1)
print('Q2 = ',Q2)
print('Q3 = ',Q3)
# Out:
# Q1 =  2013.0
# Q2 =  2015.0
# Q3 =  2017.0

# %%
IQR = Q3-Q1
low_lim = Q1-(1.5*IQR)
up_lim = Q3+(1.5*IQR)
print ('IQR =',IQR)
print ('Lower limit =',low_lim)
print ('Upper limit =',up_lim)
outlier = []
for x in data_set1['year']:
  if ((x > up_lim) or (x < low_lim)): 
    outlier.append(x)
outlier
# Out:
# IQR = 4.0
# Lower limit = 2007.0
# Upper limit = 2023.0
# [2004,
#  2006,
#  2006,
#  2000,
#  2004,
#  2005,
#  2005,
#  2005,
#  2006,
#  2005,
#  2002,
#  2000,
#  2005,
#  2006,
#  2005,
#  2004,
#  1999,
#  2006,
#  2005,
#  2006,
#  2005,
#  2003,
#  1997,
#  2004,
#  2003,
#  2005,
#  2003,
#  2006,
#  2006,
#  2005,
#  2006,
#  2004,
#  2005,
#  2003,
#  2006,
#  2004,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2004,
#  2005,
#  1999,
#  2006,
#  2002,
#  2000,
#  1999,
#  2005,
#  2001,
#  2006,
#  2003,
#  2003,
#  2004,
#  2001,
#  1999,
#  2006,
#  2005,
#  2001,
#  2006,
#  2003,
#  2006,
#  2006,
#  2006,
#  1992,
#  2006,
#  2001,
#  2005,
#  2005,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2005,
#  2002,
#  2006,
#  2004,
#  2003,
#  2006,
#  2005,
#  2004,
#  2003,
#  2006,
#  2006,
#  2005,
#  2004,
#  2006,
#  2006,
#  2006,
#  2006,
#  2002,
#  2004,
#  2004,
#  2005,
#  2006,
#  2006,
#  2001,
#  2006,
#  2006,
#  2000,
#  2004,
#  2006,
#  2005,
#  2006,
#  2000,
#  2002,
#  1999,
#  1999,
#  2005,
#  2002,
#  2003,
#  2003,
#  2006,
#  2005,
#  2005,
#  2005,
#  2003,
#  2005,
#  2006,
#  2006,
#  2006,
#  2004,
#  2006,
#  1999,
#  2006,
#  2005,
#  2004,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2005,
#  2006,
#  2006,
#  2003,
#  2006,
#  2006,
#  2001,
#  2005,
#  2004,
#  2004,
#  2004,
#  2006,
#  2004,
#  2005,
#  2006,
#  2006,
#  2006,
#  2006,
#  2004,
#  2004,
#  2005,
#  2000,
#  2006,
#  2005,
#  2006,
#  2003,
#  1999,
#  2006,
#  2004,
#  2003,
#  2005,
#  2001,
#  2006,
#  2003,
#  2005,
#  1998,
#  2005,
#  2006,
#  2004,
#  2004,
#  2004,
#  2000,
#  2001,
#  1998,
#  2006,
#  2006,
#  2006,
#  1999,
#  2002,
#  2006,
#  2006,
#  2000,
#  2006,
#  2006,
#  2005,
#  2001,
#  2006,
#  2003,
#  2003,
#  2004,
#  2006,
#  2005,
#  1998,
#  2004,
#  2006,
#  2006,
#  2003,
#  2004,
#  2006,
#  2006,
#  1998,
#  2006,
#  2005,
#  2006,
#  2005,
#  2006,
#  2006,
#  2002,
#  2001,
#  2006,
#  2006,
#  2004,
#  1999,
#  2000,
#  2006,
#  2006,
#  2002,
#  2006,
#  2006,
#  2004,
#  2005,
#  2003,
#  2005,
#  2006,
#  2002,
#  2006,
#  2006,
#  2006,
#  2002,
#  2006,
#  2002,
#  2006,
#  2006,
#  2006,
#  2000,
#  2006,
#  2006,
#  2000,
#  2002,
#  2005,
#  2004,
#  2005,
#  2006,
#  2005,
#  2001,
#  2003,
#  2006,
#  2006,
#  2006,
#  2005,
#  2003,
#  2005,
#  2005,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2006,
#  2004,
#  2006,
#  2000,
#  2006,
#  2006,
#  2005,
#  2005,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2006,
#  1998,
#  2003,
#  2006,
#  2006,
#  2004,
#  2005,
#  2006,
#  2004,
#  2001,
#  2006,
#  2006,
#  2002,
#  2006,
#  2002,
#  2004,
#  2006,
#  2006,
#  2006,
#  2005,
#  2005,
#  2006,
#  2002,
#  2004,
#  2000,
#  2006,
#  2004,
#  2006,
#  2001,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2006,
#  2004,
#  2006,
#  2005,
#  2005,
#  2006,
#  2006,
#  1999,
#  2004,
#  2006,
#  2006,
#  2005,
#  2001,
#  2004,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  1999,
#  2006,
#  1991,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2004,
#  1998,
#  2004,
#  2005,
#  2006,
#  2006,
#  2006,
#  2004,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2006,
#  2006,
#  2001,
#  2006,
#  2006,
#  1996]

# %%
data_set1['year']=np.where(data_set1['year']>up_lim,up_lim,np.where(data_set1['year']<low_lim,low_lim,data_set1['year']))
data_set1
# Out:
#                                             full_name  ...  seats
# 0                                     Maruti Alto Std  ...      5
# 1                              Hyundai Grand i10 Asta  ...      5
# 2                                    Hyundai i20 Asta  ...      5
# 3                       Maruti Alto K10 2010-2014 VXI  ...      5
# 4      Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV  ...      5
# ...                                               ...  ...    ...
# 19969                   Toyota Platinum Etios 1.4 GXD  ...      5
# 19970                          Maruti Ertiga BSIV VXI  ...      7
# 19971                    Skoda Rapid 1.5 TDI Elegance  ...      5
# 19972                          Mahindra XUV500 W6 2WD  ...      7
# 19973                        Honda City i-VTEC CVT VX  ...      5
#
# [19974 rows x 13 columns]

# %%
plt.boxplot(data_set1['year'])
plt.title('Box plot of year')
# Out:
# Text(0.5, 1.0, 'Box plot of year')

# %%
plt.boxplot(data_set1['km_driven'])
plt.title('Box plot of Kilometers Driven')
# Out:
# Text(0.5, 1.0, 'Box plot of Kilometers Driven')

# %%
Q1=np.percentile(data_set1['km_driven'],25,interpolation='midpoint')
Q2=np.percentile(data_set1['km_driven'],50,interpolation='midpoint')
Q3=np.percentile(data_set1['km_driven'],75,interpolation='midpoint')
print('Q1 = ',Q1)
print('Q2 = ',Q2)
print('Q3 = ',Q3)
# Out:
# Q1 =  31117.0
# Q2 =  52000.0
# Q3 =  74000.0

# %%
IQR = Q3-Q1
low_lim = Q1-(1.5*IQR)
up_lim = Q3+(1.5*IQR)
print ('IQR =',IQR)
print ('Lower limit =',low_lim)
print ('Upper limit =',up_lim)
outlier = []
for x in data_set1['km_driven']:
  if ((x > up_lim) or (x < low_lim)): 
    outlier.append(x)
outlier
# Out:
# IQR = 42883.0
# Lower limit = -33207.5
# Upper limit = 138324.5
# [185000.0,
#  190000.0,
#  160000.0,
#  160000.0,
#  240000.0,
#  165000.0,
#  185000.0,
#  280000.0,
#  220000.0,
#  170000.0,
#  162828.0,
#  250000.0,
#  142587.0,
#  160800.0,
#  350000.0,
#  155000.0,
#  140000.0,
#  160000.0,
#  150000.0,
#  280000.0,
#  155000.0,
#  143000.0,
#  200000.0,
#  187031.0,
#  170000.0,
#  163000.0,
#  208000.0,
#  148000.0,
#  160000.0,
#  190000.0,
#  175000.0,
#  144000.0,
#  150000.0,
#  174926.0,
#  150000.0,
#  140000.0,
#  387000.0,
#  150000.0,
#  215000.0,
#  228000.0,
#  200000.0,
#  150000.0,
#  170000.0,
#  150000.0,
#  140000.0,
#  185000.0,
#  170000.0,
#  170000.0,
#  162000.0,
#  148736.0,
#  186000.0,
#  215000.0,
#  147000.0,
#  147626.0,
#  160000.0,
#  227000.0,
#  200000.0,
#  250000.0,
#  160000.0,
#  170000.0,
#  145000.0,
#  150000.0,
#  155000.0,
#  187500.0,
#  140000.0,
#  200000.0,
#  295000.0,
#  242924.0,
#  160000.0,
#  190000.0,
#  200000.0,
#  177000.0,
#  150000.0,
#  158000.0,
#  184000.0,
#  230000.0,
#  215000.0,
#  186000.0,
#  142000.0,
#  158000.0,
#  145000.0,
#  140000.0,
#  164000.0,
#  200000.0,
#  174000.0,
#  145000.0,
#  165999.0,
#  191876.0,
#  500000.0,
#  177000.0,
#  140000.0,
#  257000.0,
#  190000.0,
#  210000.0,
#  161209.0,
#  142000.0,
#  198000.0,
#  160000.0,
#  225000.0,
#  176126.0,
#  180000.0,
#  195000.0,
#  168000.0,
#  167200.0,
#  150000.0,
#  140165.0,
#  161445.0,
#  230000.0,
#  187420.0,
#  190000.0,
#  165000.0,
#  164000.0,
#  170000.0,
#  150000.0,
#  175000.0,
#  255000.0,
#  220000.0,
#  570000.0,
#  190000.0,
#  150000.0,
#  180000.0,
#  142000.0,
#  204983.0,
#  175645.0,
#  150000.0,
#  170000.0,
#  147000.0,
#  183000.0,
#  199253.0,
#  143000.0,
#  168877.0,
#  197000.0,
#  220000.0,
#  168000.0,
#  280000.0,
#  211121.0,
#  240000.0,
#  315000.0,
#  277000.0,
#  461000.0,
#  217000.0,
#  158000.0,
#  170000.0,
#  180000.0,
#  138886.0,
#  150000.0,
#  780000.0,
#  173758.0,
#  145000.0,
#  154000.0,
#  200000.0,
#  146000.0,
#  208000.0,
#  151350.0,
#  140000.0,
#  148000.0,
#  190000.0,
#  186000.0,
#  142222.0,
#  163971.0,
#  156000.0,
#  350000.0,
#  160000.0,
#  270000.0,
#  154667.0,
#  139000.0,
#  152000.0,
#  142800.0,
#  140000.0,
#  140000.0,
#  160000.0,
#  276000.0,
#  140000.0,
#  198000.0,
#  150000.0,
#  150000.0,
#  142996.0,
#  147000.0,
#  209000.0,
#  182340.0,
#  185000.0,
#  141000.0,
#  150000.0,
#  158000.0,
#  233000.0,
#  270000.0,
#  400000.0,
#  850000.0,
#  361446.0,
#  150624.0,
#  228104.0,
#  150000.0,
#  162245.0,
#  216000.0,
#  185000.0,
#  160000.0,
#  200000.0,
#  162000.0,
#  139000.0,
#  138489.0,
#  171289.0,
#  139352.0,
#  140000.0,
#  150000.0,
#  185000.0,
#  153000.0,
#  192000.0,
#  147000.0,
#  150000.0,
#  220000.0,
#  178000.0,
#  147000.0,
#  160000.0,
#  275000.0,
#  151315.0,
#  180000.0,
#  199900.0,
#  159000.0,
#  146000.0,
#  170000.0,
#  212000.0,
#  150000.0,
#  175000.0,
#  158000.0,
#  147550.0,
#  200000.0,
#  190000.0,
#  200000.0,
#  254000.0,
#  200000.0,
#  145953.0,
#  300000.0,
#  150000.0,
#  200000.0,
#  150000.0,
#  150000.0,
#  160000.0,
#  425000.0,
#  150000.0,
#  200000.0,
#  312000.0,
#  210000.0,
#  144362.0,
#  154000.0,
#  190000.0,
#  170000.0,
#  160000.0,
#  144000.0,
#  160000.0,
#  173000.0,
#  230000.0,
#  158000.0,
#  280000.0,
#  185000.0,
#  192000.0,
#  150000.0,
#  270000.0,
#  161728.0,
#  157000.0,
#  200000.0,
#  214000.0,
#  150000.0,
#  145000.0,
#  293672.0,
#  200000.0,
#  310000.0,
#  165000.0,
#  146000.0,
#  155000.0,
#  149000.0,
#  165000.0,
#  148533.0,
#  180000.0,
#  190000.0,
#  144653.0,
#  170000.0,
#  151000.0,
#  221000.0,
#  180487.0,
#  295000.0,
#  140000.0,
#  153000.0,
#  143210.0,
#  141000.0,
#  191542.0,
#  198565.0,
#  179000.0,
#  220000.0,
#  140000.0,
#  140000.0,
#  160000.0,
#  300000.0,
#  162000.0,
#  300000.0,
#  170000.0,
#  140000.0,
#  155000.0,
#  299575.0,
#  142000.0,
#  180000.0,
#  300000.0,
#  222387.0,
#  175000.0,
#  145000.0,
#  200000.0,
#  157000.0,
#  200000.0,
#  180000.0,
#  260000.0,
#  293000.0,
#  190000.0,
#  169000.0,
#  333000.0,
#  180000.0,
#  175000.0,
#  194532.0,
#  146000.0,
#  185000.0,
#  150000.0,
#  170000.0,
#  230000.0,
#  156000.0,
#  830000.0,
#  155522.0,
#  148000.0,
#  140000.0,
#  181000.0,
#  175000.0,
#  140000.0,
#  144321.0,
#  150000.0,
#  150420.0,
#  163876.0,
#  151000.0,
#  143746.0,
#  151000.0,
#  233000.0,
#  390000.0,
#  179000.0,
#  145495.0,
#  175000.0,
#  165856.0,
#  195000.0,
#  300000.0,
#  180000.0,
#  165000.0,
#  200000.0,
#  214000.0,
#  146781.0,
#  720000.0,
#  180000.0,
#  140000.0,
#  170000.0,
#  349000.0,
#  288500.0,
#  177000.0,
#  160000.0,
#  145000.0,
#  189000.0,
#  195000.0,
#  590000.0,
#  200000.0,
#  280000.0,
#  150000.0,
#  220000.0,
#  150000.0,
#  140782.0,
#  200000.0,
#  150000.0,
#  277000.0,
#  210000.0,
#  150000.0,
#  193000.0,
#  500000.0,
#  149000.0,
#  140000.0,
#  200000.0,
#  140000.0,
#  163168.0,
#  200000.0,
#  400000.0,
#  250000.0,
#  290000.0,
#  171000.0,
#  178000.0,
#  212000.0,
#  160000.0,
#  288486.0,
#  140000.0,
#  160000.0,
#  229000.0,
#  200000.0,
#  180000.0,
#  479000.0,
#  169000.0,
#  138938.0,
#  150000.0,
#  180000.0,
#  146781.0,
#  200000.0,
#  140305.0,
#  205000.0,
#  211000.0,
#  150000.0,
#  150000.0,
#  160000.0,
#  252000.0,
#  142000.0,
#  199000.0,
#  170000.0,
#  181684.0,
#  260000.0,
#  150000.0,
#  250000.0,
#  186900.0,
#  150000.0,
#  140000.0,
#  139830.0,
#  160000.0,
#  161000.0,
#  950000.0,
#  150000.0,
#  150000.0,
#  165000.0,
#  140000.0,
#  225000.0,
#  180000.0,
#  250000.0,
#  350000.0,
#  150000.0,
#  142000.0,
#  165000.0,
#  196777.0,
#  340000.0,
#  167500.0,
#  143000.0,
#  154600.0,
#  182432.0,
#  185000.0,
#  675000.0,
#  200000.0,
#  185000.0,
#  140000.0,
#  147000.0,
#  360101.0,
#  143000.0,
#  145000.0,
#  190000.0,
#  150000.0,
#  170000.0,
#  480000.0,
#  199000.0,
#  260000.0,
#  420000.0,
#  525000.0,
#  245000.0,
#  143000.0,
#  750000.0,
#  480000.0,
#  143000.0,
#  170000.0,
#  157000.0,
#  165000.0,
#  825000.0,
#  147000.0,
#  177000.0,
#  200000.0,
#  150000.0,
#  240000.0,
#  197000.0,
#  187000.0,
#  160180.0,
#  140000.0,
#  215000.0,
#  315000.0,
#  156000.0,
#  203125.0,
#  820000.0,
#  186000.0,
#  213141.0,
#  173000.0,
#  148712.0,
#  150000.0,
#  175000.0,
#  145000.0,
#  210000.0,
#  156831.0,
#  200000.0,
#  213813.0,
#  1325000.0,
#  160000.0,
#  180000.0,
#  151000.0,
#  158648.0,
#  185000.0,
#  152000.0,
#  155000.0,
#  140000.0,
#  150000.0,
#  213000.0,
#  156000.0,
#  165000.0,
#  177000.0,
#  150000.0,
#  149028.0,
#  225000.0,
#  147500.0,
#  167000.0,
#  200000.0,
#  156000.0,
#  147000.0,
#  142500.0,
#  150000.0,
#  140000.0,
#  150000.0,
#  148000.0,
#  890000.0,
#  148000.0,
#  244400.0,
#  146000.0,
#  170000.0,
#  198000.0,
#  151768.0,
#  152358.0,
#  150821.0,
#  198000.0,
#  190000.0,
#  150000.0,
#  160000.0,
#  156000.0,
#  158000.0,
#  214000.0,
#  140000.0,
#  180000.0,
#  225000.0,
#  189000.0,
#  213000.0,
#  225000.0,
#  175000.0,
#  140451.0,
#  160000.0,
#  170000.0,
#  220000.0,
#  150000.0,
#  425785.0,
#  140000.0,
#  145000.0,
#  143000.0,
#  180000.0,
#  180000.0,
#  168986.0,
#  165000.0,
#  193000.0,
#  143448.0,
#  180000.0,
#  320000.0,
#  167919.0,
#  147000.0,
#  189000.0,
#  150000.0,
#  178000.0,
#  200000.0,
#  170000.0,
#  145000.0,
#  140000.0,
#  149500.0,
#  450000.0,
#  190000.0,
#  178000.0,
#  266007.0,
#  161823.0,
#  210000.0,
#  160000.0,
#  139000.0,
#  220000.0,
#  1485000.0,
#  225000.0,
#  250000.0,
#  450003.0,
#  139000.0,
#  170000.0,
#  177608.0,
#  200000.0,
#  200000.0,
#  190000.0,
#  150000.0,
#  200000.0,
#  140000.0,
#  160000.0,
#  174000.0,
#  157000.0,
#  145000.0,
#  160000.0,
#  179000.0,
#  163000.0,
#  172000.0,
#  147000.0,
#  151037.0,
#  151500.0,
#  200000.0,
#  223000.0,
#  193000.0,
#  175000.0,
#  153000.0,
#  147000.0,
#  189690.0,
#  200200.0,
#  145000.0,
#  142000.0,
#  146000.0,
#  170000.0,
#  140000.0,
#  186000.0,
#  158000.0,
#  148000.0,
#  195000.0,
#  170000.0,
#  140000.0,
#  155000.0,
#  150000.0,
#  200000.0,
#  176905.0,
#  270000.0,
#  148400.0,
#  140000.0,
#  140000.0,
#  150000.0,
#  151048.0,
#  270000.0,
#  180000.0,
#  150000.0,
#  190000.0,
#  220000.0,
#  140000.0,
#  170000.0,
#  3800000.0]

# %%
data_set1['km_driven']=np.where(data_set1['km_driven']>up_lim,up_lim,np.where(data_set1['km_driven']<low_lim,low_lim,data_set1['km_driven']))
data_set1
# Out:
#                                             full_name  ...  seats
# 0                                     Maruti Alto Std  ...      5
# 1                              Hyundai Grand i10 Asta  ...      5
# 2                                    Hyundai i20 Asta  ...      5
# 3                       Maruti Alto K10 2010-2014 VXI  ...      5
# 4      Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV  ...      5
# ...                                               ...  ...    ...
# 19969                   Toyota Platinum Etios 1.4 GXD  ...      5
# 19970                          Maruti Ertiga BSIV VXI  ...      7
# 19971                    Skoda Rapid 1.5 TDI Elegance  ...      5
# 19972                          Mahindra XUV500 W6 2WD  ...      7
# 19973                        Honda City i-VTEC CVT VX  ...      5
#
# [19974 rows x 13 columns]

# %%
plt.boxplot(data_set1['km_driven'])
plt.title('Box plot of Kilometers Driven')
# Out:
# Text(0.5, 1.0, 'Box plot of Kilometers Driven')

# %% [markdown]
# ### Label encoding

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()
data_set1.seller_type = le.fit_transform(data_set1.seller_type)
data_set1.fuel_type = le.fit_transform(data_set1.fuel_type)
data_set1.transmission_type = le.fit_transform(data_set1.transmission_type)

# %%
data_set1
# Out:
#                                             full_name  ...  seats
# 0                                     Maruti Alto Std  ...      5
# 1                              Hyundai Grand i10 Asta  ...      5
# 2                                    Hyundai i20 Asta  ...      5
# 3                       Maruti Alto K10 2010-2014 VXI  ...      5
# 4      Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV  ...      5
# ...                                               ...  ...    ...
# 19969                   Toyota Platinum Etios 1.4 GXD  ...      5
# 19970                          Maruti Ertiga BSIV VXI  ...      7
# 19971                    Skoda Rapid 1.5 TDI Elegance  ...      5
# 19972                          Mahindra XUV500 W6 2WD  ...      7
# 19973                        Honda City i-VTEC CVT VX  ...      5
#
# [19974 rows x 13 columns]

# %%
data_set1.head(5)
# Out:
#                                         full_name  ...  seats
# 0                                 Maruti Alto Std  ...      5
# 1                          Hyundai Grand i10 Asta  ...      5
# 2                                Hyundai i20 Asta  ...      5
# 3                   Maruti Alto K10 2010-2014 VXI  ...      5
# 4  Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV  ...      5
#
# [5 rows x 13 columns]

# %% [markdown]
# ### Feature reduction
#
# #### As more than 50% of the values in the  column new_price are null, we can drop the column. The column owner_type is having a single value, which may not contribute to the data set modelling

# %%
y=data_set1['selling_price']
X=data_set1.drop(['new_price','owner_type'],axis=1)
X.describe()
# Out:
#        selling_price          year  ...     fuel_type  transmission_type
# count   1.997400e+04  19974.000000  ...  19974.000000       19974.000000
# mean    7.392945e+05   2014.575999  ...      2.457845           0.802293
# std     9.104001e+05      3.092639  ...      1.517765           0.398280
# min     2.500000e+04   2007.000000  ...      0.000000           0.000000
# 25%     3.400000e+05   2013.000000  ...      1.000000           1.000000
# 50%     5.200000e+05   2015.000000  ...      1.000000           1.000000
# 75%     7.850000e+05   2017.000000  ...      4.000000           1.000000
# max     3.950000e+07   2021.000000  ...      4.000000           1.000000
#
# [8 rows x 6 columns]

# %%
data_set1.describe(include='all')
# Out:
#                      full_name  selling_price  ... max_power    seats
# count                    19974   1.997400e+04  ...   19974.0  19974.0
# unique                    3321            NaN  ...     489.0     10.0
# top     Maruti Swift Dzire VDI            NaN  ...      74.0      5.0
# freq                       210            NaN  ...     867.0  16585.0
# mean                       NaN   7.392945e+05  ...       NaN      NaN
# std                        NaN   9.104001e+05  ...       NaN      NaN
# min                        NaN   2.500000e+04  ...       NaN      NaN
# 25%                        NaN   3.400000e+05  ...       NaN      NaN
# 50%                        NaN   5.200000e+05  ...       NaN      NaN
# 75%                        NaN   7.850000e+05  ...       NaN      NaN
# max                        NaN   3.950000e+07  ...       NaN      NaN
#
# [11 rows x 13 columns]

# %% [markdown]
# ### Feature Engineering

# %%
data_set1.rename(columns={'full_name':'company'}, inplace=True)
data_set1.dtypes
# Out:
# company               object
# selling_price        float64
# new_price             object
# year                 float64
# seller_type            int64
# km_driven            float64
# owner_type            object
# fuel_type              int64
# transmission_type      int64
# mileage               object
# engine                object
# max_power             object
# seats                 object
# dtype: object
